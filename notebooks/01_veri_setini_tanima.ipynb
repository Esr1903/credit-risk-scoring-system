# %%
import pandas as pd

# %%
data_path = "../data/raw/SouthGermanCredit.asc"

# %%
import os

os.path.exists(data_path)
# Out:
# True

# %%
df = pd.read_csv(data_path, sep=" ")

# %%
df.shape
# Out:
# (1000, 21)

# %%
df.head()
# Out:
#    laufkont  laufzeit  moral  verw  hoehe  sparkont  beszeit  rate  famges  \
# 0         1        18      4     2   1049         1        2     4       2
# 1         1         9      4     0   2799         1        3     2       3
# 2         2        12      2     9    841         2        4     2       2
# 3         1        12      4     0   2122         1        3     3       3
# 4         1        12      4     0   2171         1        3     4       3
#
#    buerge  ...  verm  alter  weitkred  wohn  bishkred  beruf  pers  telef  \
# 0       1  ...     2     21         3     1         1      3     2      1
# 1       1  ...     1     36         3     1         2      3     1      1
# 2       1  ...     1     23         3     1         1      2     2      1
# 3       1  ...     1     39         3     1         2      2     1      1
# 4       1  ...     2     38         1     2         2      2     2      1
#
#    gastarb  kredit
# 0        2       1
# 1        2       1
# ...

# %%
df.columns.tolist()
# Out:
# ['laufkont',
#  'laufzeit',
#  'moral',
#  'verw',
#  'hoehe',
#  'sparkont',
#  'beszeit',
#  'rate',
#  'famges',
#  'buerge',
#  'wohnzeit',
#  'verm',
#  'alter',
#  'weitkred',
#  'wohn',
#  'bishkred',
#  'beruf',
#  'pers',
#  'telef',
#  'gastarb',
#  'kredit']

# %%
df["kredit"].value_counts()
# Out:
# kredit
# 1    700
# 0    300
# Name: count, dtype: int64

# %%
df["kredit"].value_counts(normalize=True) * 100
# Out:
# kredit
# 1    70.0
# 0    30.0
# Name: proportion, dtype: float64

# %%
df.dtypes
# Out:
# laufkont    int64
# laufzeit    int64
# moral       int64
# verw        int64
# hoehe       int64
# sparkont    int64
# beszeit     int64
# rate        int64
# famges      int64
# buerge      int64
# wohnzeit    int64
# verm        int64
# alter       int64
# weitkred    int64
# wohn        int64
# bishkred    int64
# beruf       int64
# pers        int64
# telef       int64
# gastarb     int64
# kredit      int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# laufkont    0
# laufzeit    0
# moral       0
# verw        0
# hoehe       0
# sparkont    0
# beszeit     0
# rate        0
# famges      0
# buerge      0
# wohnzeit    0
# verm        0
# alter       0
# weitkred    0
# wohn        0
# bishkred    0
# beruf       0
# pers        0
# telef       0
# gastarb     0
# kredit      0
# dtype: int64

# %%
df.describe()
# Out:
#           laufkont     laufzeit       moral         verw        hoehe  \
# count  1000.000000  1000.000000  1000.00000  1000.000000   1000.00000
# mean      2.577000    20.903000     2.54500     2.828000   3271.24800
# std       1.257638    12.058814     1.08312     2.744439   2822.75176
# min       1.000000     4.000000     0.00000     0.000000    250.00000
# 25%       1.000000    12.000000     2.00000     1.000000   1365.50000
# 50%       2.000000    18.000000     2.00000     2.000000   2319.50000
# 75%       4.000000    24.000000     4.00000     3.000000   3972.25000
# max       4.000000    72.000000     4.00000    10.000000  18424.00000
#
#           sparkont      beszeit         rate      famges       buerge  ...  \
# count  1000.000000  1000.000000  1000.000000  1000.00000  1000.000000  ...
# mean      2.105000     3.384000     2.973000     2.68200     1.145000  ...
# std       1.580023     1.208306     1.118715     0.70808     0.477706  ...
# ...

# %%
column_names = {
    "laufkont": "status",
    "laufzeit": "duration",
    "moral": "credit_history",
    "verw": "purpose",
    "hoehe": "amount",
    "sparkont": "savings",
    "beszeit": "employment_duration",
    "rate": "installment_rate",
    "famges": "personal_status_sex",
    "buerge": "other_debtors",
    "wohnzeit": "present_residence",
    "verm": "property",
    "alter": "age",
    "weitkred": "other_installment_plans",
    "wohn": "housing",
    "bishkred": "number_credits",
    "beruf": "job",
    "pers": "people_liable",
    "telef": "telephone",
    "gastarb": "foreign_worker",
    "kredit": "credit_risk"
}

# %%
df_renamed = df.rename(columns=column_names)

# %%
df_renamed.columns.tolist()
# Out:
# ['status',
#  'duration',
#  'credit_history',
#  'purpose',
#  'amount',
#  'savings',
#  'employment_duration',
#  'installment_rate',
#  'personal_status_sex',
#  'other_debtors',
#  'present_residence',
#  'property',
#  'age',
#  'other_installment_plans',
#  'housing',
#  'number_credits',
#  'job',
#  'people_liable',
#  'telephone',
#  'foreign_worker',
#  'credit_risk']

# %%
df_renamed.head()
# Out:
#    status  duration  credit_history  purpose  amount  savings  \
# 0       1        18               4        2    1049        1
# 1       1         9               4        0    2799        1
# 2       2        12               2        9     841        2
# 3       1        12               4        0    2122        1
# 4       1        12               4        0    2171        1
#
#    employment_duration  installment_rate  personal_status_sex  other_debtors  \
# 0                    2                 4                    2              1
# 1                    3                 2                    3              1
# 2                    4                 2                    2              1
# 3                    3                 3                    3              1
# 4                    3                 4                    3              1
#
#    ...  property  age  other_installment_plans  housing  number_credits  job  \
# ...

# %%
df_renamed["credit_risk"].value_counts()
# Out:
# credit_risk
# 1    700
# 0    300
# Name: count, dtype: int64

# %%
processed_path = "../data/processed/south_german_credit_clean.csv"

df_renamed.to_csv(processed_path, index=False)
